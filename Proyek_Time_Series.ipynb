# %%
# import library
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# read dataset
df = pd.read_csv('https://query.data.world/s/tu7xkafdc4jbuzmuh5zxqaeshwj7sv', encoding = 'unicode_escape')
df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 0  1849-01-01              26.704                          1.435  Abidjan
# 1  1849-02-01              27.434                          1.362  Abidjan
# 2  1849-03-01              28.101                          1.612  Abidjan
# 3  1849-04-01              26.140                          1.387  Abidjan
# 4  1849-05-01              25.427                          1.200  Abidjan
#
#           Country Latitude Longitude
# 0  C̫te D'Ivoire    5.63N     3.23W
# 1  C̫te D'Ivoire    5.63N     3.23W
# 2  C̫te D'Ivoire    5.63N     3.23W
# 3  C̫te D'Ivoire    5.63N     3.23W
# 4  C̫te D'Ivoire    5.63N     3.23W

# %%
# drop kolom
df.drop(['City', 'Latitude', 'Longitude'], axis = 1, inplace = True)
display(df)
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1849-01-01              26.704                          1.435
# 1       1849-02-01              27.434                          1.362
# 2       1849-03-01              28.101                          1.612
# 3       1849-04-01              26.140                          1.387
# 4       1849-05-01              25.427                          1.200
# ...            ...                 ...                            ...
# 239172  2013-05-01              18.979                          0.807
# 239173  2013-06-01              23.522                          0.647
# 239174  2013-07-01              25.251                          1.042
# 239175  2013-08-01              24.528                          0.840
# 239176  2013-09-01                 NaN                            NaN
#
#                Country
# 0       C̫te D'Ivoire
# 1       C̫te D'Ivoire
# 2       C̫te D'Ivoire
# 3       C̫te D'Ivoire
# 4       C̫te D'Ivoire
# ...                ...
# 239172           China
# 239173           China
# 239174           China
# 239175           China
# 239176           China
#
# [239177 rows x 4 columns]

# %%
# ambil data 1945-2013
df['dt'] = pd.to_datetime(df['dt'])
get_data = (df['dt'] > '1945-01-01') & (df['dt'] <= '2013-09-01')
df.loc[get_data]

df = df.loc[get_data]
display(df)
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty  \
# 1153   1945-02-01              27.933                          0.394
# 1154   1945-03-01              28.512                          0.354
# 1155   1945-04-01              27.967                          0.438
# 1156   1945-05-01              27.193                          0.301
# 1157   1945-06-01              25.786                          0.237
# ...           ...                 ...                            ...
# 239172 2013-05-01              18.979                          0.807
# 239173 2013-06-01              23.522                          0.647
# 239174 2013-07-01              25.251                          1.042
# 239175 2013-08-01              24.528                          0.840
# 239176 2013-09-01                 NaN                            NaN
#
#                Country
# 1153    C̫te D'Ivoire
# 1154    C̫te D'Ivoire
# 1155    C̫te D'Ivoire
# 1156    C̫te D'Ivoire
# 1157    C̫te D'Ivoire
# ...                ...
# 239172           China
# 239173           China
# 239174           China
# 239175           China
# 239176           China
#
# [82400 rows x 4 columns]

# %%
# ambil data negara India
df = df.loc[df['Country'].isin(['India'])]
display(df)
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty Country
# 5731   1945-02-01              21.127                          0.315   India
# 5732   1945-03-01              26.643                          0.352   India
# 5733   1945-04-01              29.685                          0.696   India
# 5734   1945-05-01              32.437                          0.388   India
# 5735   1945-06-01              32.142                          0.606   India
# ...           ...                 ...                            ...     ...
# 216560 2013-05-01              32.980                          1.097   India
# 216561 2013-06-01              29.418                          0.527   India
# 216562 2013-07-01              27.306                          0.257   India
# 216563 2013-08-01              27.187                          0.129   India
# 216564 2013-09-01                 NaN                            NaN   India
#
# [11536 rows x 4 columns]

# %%
# drop kolom
df.drop(['Country'], axis = 1, inplace = True)
df.reset_index(drop = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#               dt  AverageTemperature  AverageTemperatureUncertainty
# 0     1945-02-01              21.127                          0.315
# 1     1945-03-01              26.643                          0.352
# 2     1945-04-01              29.685                          0.696
# 3     1945-05-01              32.437                          0.388
# 4     1945-06-01              32.142                          0.606
# ...          ...                 ...                            ...
# 11531 2013-05-01              32.980                          1.097
# 11532 2013-06-01              29.418                          0.527
# 11533 2013-07-01              27.306                          0.257
# 11534 2013-08-01              27.187                          0.129
# 11535 2013-09-01                 NaN                            NaN
#
# [11536 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# dt                                0
# AverageTemperature               14
# AverageTemperatureUncertainty    14
# dtype: int64

# %%
df.dropna(subset = ['AverageTemperature'], inplace = True)
df.dropna(subset = ['AverageTemperatureUncertainty'], inplace = True)
df.isnull().sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# dt                               0
# AverageTemperature               0
# AverageTemperatureUncertainty    0
# dtype: int64

# %%
df_plot = df
df_plot[df_plot.columns.to_list()].plot(subplots = True, figsize = (20, 10))
plt.show()

# %%
dates = df['dt'].values
temp = df['AverageTemperature'].values

dates = np.array(dates)
temp = np.array(temp)

plt.figure(figsize = (20, 10))
plt.plot(dates, temp)

plt.title('Average Temperature', fontsize = 15)
plt.ylabel('Temperature')
plt.xlabel('Datetime')
# Out:
# Text(0.5, 0, 'Datetime')

# %%
df.dtypes
# Out:
# dt                               datetime64[ns]
# AverageTemperature                      float64
# AverageTemperatureUncertainty           float64
# dtype: object

# %%
# split dataset
from sklearn.model_selection import train_test_split
x_train, x_valid, y_train, y_valid = train_test_split(temp, dates, train_size = 0.8, test_size = 0.2, shuffle = False)

print('Jumlah Data Train : ', len(x_train))
print('Jumlah Data Validation : ', len(x_valid))

def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
  series = tf.expand_dims(series, axis = -1)
  ds = tf.data.Dataset.from_tensor_slices(series)
  ds = ds.window(window_size + 1, shift = 1, drop_remainder = True)
  ds = ds.flat_map(lambda w : w.batch(window_size + 1))
  ds = ds.shuffle(shuffle_buffer)
  ds = ds.map(lambda w : (w[:-1], w[-1:]))
  return ds.batch(batch_size).prefetch(1)
# Out:
# Jumlah Data Train :  9217
# Jumlah Data Validation :  2305

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dense,Bidirectional,Dropout

tf.keras.backend.set_floatx('float64')

train_set = windowed_dataset(x_train, window_size = 64, batch_size = 200, shuffle_buffer = 1000)
val_set = windowed_dataset(x_valid, window_size = 64, batch_size = 200, shuffle_buffer = 1000)

model = Sequential([
    Bidirectional(LSTM(60, return_sequences=True)),
    Bidirectional(LSTM(60)),
    Dense(30, activation="relu"),
    Dense(10, activation="relu"),
    Dense(1),
])

# %%
Mae = (df['AverageTemperature'].max() - df['AverageTemperature'].min()) * 10/100
print(Mae)
# Out:
# 2.403

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('mae') < 2.4 and logs.get('val_mae') < 2.4):
      print("Mae < 10% data")
      self.model.stop_training = True
callbacks = myCallback()

# %%
optimizer = tf.keras.optimizers.SGD(lr=1.0000e-04, momentum=0.9)

model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])
# Epoch 43/100
# 46/46 [==============================] - 43s 923ms/step - loss: 2.8083 - mae: 3.2742 - val_loss: 2.6632 - val_mae: 3.1316
# Epoch 44/100
# 46/46 [==============================] - 43s 921ms/step - loss: 2.7527 - mae: 3.2171 - val_loss: 2.6350 - val_mae: 3.1017
# Epoch 45/100
# 46/46 [==============================] - 43s 923ms/step - loss: 2.7133 - mae: 3.1747 - val_loss: 2.6428 - val_mae: 3.1065
# Epoch 46/100
# 46/46 [==============================] - 43s 924ms/step - loss: 2.6906 - mae: 3.1521 - val_loss: 2.5591 - val_mae: 3.0193
# Epoch 47/100
# 46/46 [==============================] - 43s 927ms/step - loss: 2.6403 - mae: 3.1011 - val_loss: 2.5224 - val_mae: 2.9825
# Epoch 48/100
# 46/46 [==============================] - 42s 919ms/step - loss: 2.5924 - mae: 3.0516 - val_loss: 2.4673 - val_mae: 2.9219
# Epoch 49/100
# 46/46 [==============================] - 43s 922ms/step - loss: 2.5657 - mae: 3.0263 - val_loss: 2.4331 - val_mae: 2.8930
# Epoch 50/100
# 46/46 [==============================] - 43s 924ms/step - loss: 2.5378 - mae: 2.9937 - val_loss: 2.3902 - val_mae: 2.8478
# Epoch 51/100
# 46/46 [==============================] - 43s 923ms/step - loss: 2.4886 - mae: 2.9450 - val_loss: 2.3331 - val_mae: 2.7823
# Epoch 52/100
# 46/46 [==============================] - 43s 924ms/step - loss: 2.4375 - mae: 2.8905 - val_loss: 2.2953 - val_mae: 2.7438
# Epoch 53/100
# 46/46 [==============================] - 43s 923ms/step - loss: 2.3840 - mae: 2.8373 - val_loss: 2.2532 - val_mae: 2.7048
# Epoch 54/100
# 46/46 [==============================] - 43s 925ms/step - loss: 2.3115 - mae: 2.7654 - val_loss: 2.1575 - val_mae: 2.6143
# Epoch 55/100
# 46/46 [==============================] - 43s 921ms/step - loss: 2.2518 - mae: 2.7047 - val_loss: 2.2204 - val_mae: 2.6791
# Epoch 56/100
# 46/46 [==============================] - 44s 948ms/step - loss: 2.1089 - mae: 2.5582 - val_loss: 1.9053 - val_mae: 2.3590
# Epoch 57/100
# 46/46 [==============================] - 44s 945ms/step - loss: 2.0350 - mae: 2.4838 - val_loss: 1.8476 - val_mae: 2.2973
# Epoch 58/100
# 46/46 [==============================] - 43s 924ms/step - loss: 1.9381 - mae: 2.3852 - val_loss: 1.9797 - val_mae: 2.4394
# Epoch 59/100
# 46/46 [==============================] - 43s 924ms/step - loss: 2.3981 - mae: 2.8540 - val_loss: 2.0721 - val_mae: 2.5280
# Epoch 60/100
# 46/46 [==============================] - 44s 943ms/step - loss: 2.0366 - mae: 2.4862 - val_loss: 1.6705 - val_mae: 2.1224
# Epoch 61/100
# 46/46 [==============================] - ETA: 0s - loss: 1.8653 - mae: 2.3148Mae < 10% data
# 46/46 [==============================] - 44s 949ms/step - loss: 1.8653 - mae: 2.3148 - val_loss: 1.6800 - val_mae: 2.1272

# %%
plt.plot(history.history['mae'])
plt.plot(history.history['val_mae'])
plt.title('Model Accuracy')
plt.xlabel('epoch')
plt.ylabel('Mae')
plt.legend(['Train', 'Val'], loc = 'best')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Train', 'Val'], loc = 'best')
plt.show()
